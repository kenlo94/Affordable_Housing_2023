# %% [markdown]
# <a href="https://colab.research.google.com/github/kenlo94/Affordable_Housing_2023/blob/rob_data_analytics/Solano%26Yolo_County.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SOLANO COUNTY**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

RealData_df = pd.read_csv(io.BytesIO(uploaded['Solano_County.csv']), index_col='Dates',parse_dates=True)
print(RealData_df)
# Out:
#      <input type="file" id="files-479d034b-aac7-4ec9-8406-64dde377449f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-479d034b-aac7-4ec9-8406-64dde377449f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Solano_County.csv to Solano_County.csv
#             Solano County
# Dates
# 2000-01-31         198493
# 2000-02-29         199058
# 2000-03-31         200291
# 2000-04-30         202113
# 2000-05-31         204492
# ...                   ...
# 2021-12-31         594929
# 2022-01-31         603703
# 2022-02-28         612057
# 2022-03-31         619242
# 2022-04-30         624207
#
# [268 rows x 1 columns]

# %%
RealData_df = RealData_df.dropna()
RealData_df
# Out:
#             Solano County
# Dates
# 2000-01-31         198493
# 2000-02-29         199058
# 2000-03-31         200291
# 2000-04-30         202113
# 2000-05-31         204492
# ...                   ...
# 2021-12-31         594929
# 2022-01-31         603703
# 2022-02-28         612057
# 2022-03-31         619242
# 2022-04-30         624207
#
# [268 rows x 1 columns]

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(24, 8)})
RealData_df['Solano County'].plot(linewidth=2.5);
#RealData_df.plot

# %%
len(RealData_df)
# Out:
# 268

# %%
DATOS = RealData_df['Solano County'].values

# Primero dividamos los sets entre train y test
# En este caso la partición no puede ser aleatoria
# (se debe preservar el orden de la secuencia)
TRAIN_SIZE = 0.85
idx = round(len(DATOS)*TRAIN_SIZE)
datos_train = DATOS[0:idx]
datos_test = DATOS[idx:]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()

scaler = MinMaxScaler(feature_range=(-1,1))
datos_train_s = scaler.fit_transform(datos_train.reshape(-1,1))
datos_test_s = scaler.transform(datos_test.reshape(-1,1))

LONG_SEC = 2

X_train, Y_train = [], []
for i in range(len(datos_train_s)-LONG_SEC):
  X_train.append(datos_train_s[i:i+LONG_SEC])
  Y_train.append(datos_train_s[i+LONG_SEC])

X_test, Y_test = [], []
for i in range(len(datos_test_s)-LONG_SEC):
  X_test.append(datos_test_s[i:i+LONG_SEC])
  Y_test.append(datos_test_s[i+LONG_SEC])

X_train, Y_train = np.array(X_train), np.array(Y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test, Y_test = np.array(X_test), np.array(Y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (226, 2, 1) (226, 1)
# (38, 2, 1) (38, 1)

# %%
RealData_df['Solano County'].iloc[0:idx].plot(linewidth=4.5, label='train', figsize=(24,8))
RealData_df['Solano County'].iloc[idx:].plot(linewidth=4.5, color='orange', label='test')
plt.title("SOLANO COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")
plt.xlabel('Period of Time', fontsize=35)
plt.ylabel('Prices-USD', fontsize=35)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend();

# %%
# Creating the LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop, Adam
import tensorflow as tf

# Seed for Random Generators
SEED = 88
tf.random.set_seed(SEED)
np.random.seed(SEED)

# El modelo
N_UNITS = 150
modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=(LONG_SEC,1)))
modelo.add(Dense(1))

# %%
# Compilación y entrenamiento
optimizador = RMSprop(learning_rate=0.0005)
modelo.compile(optimizer=optimizador, loss='mse', metrics='mean_absolute_error')

# Entrenamiento
EPOCHS = 60
BATCH_SIZE = 5
modelo.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
           validation_data = (X_test, Y_test))
# Out:
# Epoch 1/60
# 46/46 [==============================] - 3s 16ms/step - loss: 0.2251 - mean_absolute_error: 0.3987 - val_loss: 0.4098 - val_mean_absolute_error: 0.6020
# Epoch 2/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0443 - mean_absolute_error: 0.1661 - val_loss: 0.0367 - val_mean_absolute_error: 0.1635
# Epoch 3/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0407 - val_loss: 0.0089 - val_mean_absolute_error: 0.0676
# Epoch 4/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0375 - val_loss: 0.0081 - val_mean_absolute_error: 0.0647
# Epoch 5/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0387 - val_loss: 0.0071 - val_mean_absolute_error: 0.0613
# Epoch 6/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0383 - val_loss: 0.0029 - val_mean_absolute_error: 0.0455
# Epoch 7/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0385 - val_loss: 0.0057 - val_mean_absolute_error: 0.0558
# Epoch 8/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0386 - val_loss: 0.0021 - val_mean_absolute_error: 0.0405
# Epoch 9/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0359 - val_loss: 0.0064 - val_mean_absolute_error: 0.0598
# Epoch 10/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0382 - val_loss: 0.0077 - val_mean_absolute_error: 0.0649
# Epoch 11/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0373 - val_loss: 0.0110 - val_mean_absolute_error: 0.0820
# Epoch 12/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0362 - val_loss: 0.0095 - val_mean_absolute_error: 0.0766
# Epoch 13/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0368 - val_loss: 0.0029 - val_mean_absolute_error: 0.0458
# Epoch 14/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0358 - val_loss: 0.0025 - val_mean_absolute_error: 0.0418
# Epoch 15/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0360 - val_loss: 0.0098 - val_mean_absolute_error: 0.0762
# Epoch 16/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0358 - val_loss: 0.0162 - val_mean_absolute_error: 0.1091
# Epoch 17/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - val_loss: 0.0048 - val_mean_absolute_error: 0.0515
# Epoch 18/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0341 - val_loss: 0.0079 - val_mean_absolute_error: 0.0696
# Epoch 19/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0348 - val_loss: 0.0059 - val_mean_absolute_error: 0.0579
# Epoch 20/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0338 - val_loss: 0.0014 - val_mean_absolute_error: 0.0319
# Epoch 21/60
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0023 - mean_absolute_error: 0.0349 - val_loss: 0.0121 - val_mean_absolute_error: 0.0916
# Epoch 22/60
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_absolute_error: 0.0351 - val_loss: 0.0057 - val_mean_absolute_error: 0.0562
# Epoch 23/60
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0022 - mean_absolute_error: 0.0339 - val_loss: 0.0141 - val_mean_absolute_error: 0.0985
# Epoch 24/60
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0021 - mean_absolute_error: 0.0333 - val_loss: 0.0023 - val_mean_absolute_error: 0.0390
# Epoch 25/60
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0327 - val_loss: 0.0089 - val_mean_absolute_error: 0.0772
# Epoch 26/60
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0020 - mean_absolute_error: 0.0325 - val_loss: 0.0046 - val_mean_absolute_error: 0.0506
# Epoch 27/60
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0020 - mean_absolute_error: 0.0324 - val_loss: 0.0091 - val_mean_absolute_error: 0.0784
# Epoch 28/60
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0309 - val_loss: 0.0049 - val_mean_absolute_error: 0.0524
# Epoch 29/60
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0308 - val_loss: 0.0024 - val_mean_absolute_error: 0.0373
# Epoch 30/60
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0307 - val_loss: 0.0027 - val_mean_absolute_error: 0.0392
# Epoch 31/60
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0018 - mean_absolute_error: 0.0307 - val_loss: 0.0054 - val_mean_absolute_error: 0.0559
# Epoch 32/60
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0297 - val_loss: 0.0035 - val_mean_absolute_error: 0.0435
# Epoch 33/60
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0016 - mean_absolute_error: 0.0271 - val_loss: 0.0016 - val_mean_absolute_error: 0.0320
# Epoch 34/60
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0295 - val_loss: 0.0033 - val_mean_absolute_error: 0.0433
# Epoch 35/60
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0280 - val_loss: 7.8894e-04 - val_mean_absolute_error: 0.0243
# Epoch 36/60
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0016 - mean_absolute_error: 0.0283 - val_loss: 0.0019 - val_mean_absolute_error: 0.0336
# Epoch 37/60
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0015 - mean_absolute_error: 0.0275 - val_loss: 0.0015 - val_mean_absolute_error: 0.0295
# Epoch 38/60
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0015 - mean_absolute_error: 0.0277 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 39/60
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0014 - mean_absolute_error: 0.0266 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 40/60
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0014 - mean_absolute_error: 0.0264 - val_loss: 0.0095 - val_mean_absolute_error: 0.0877
# Epoch 41/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 9.3681e-04 - val_mean_absolute_error: 0.0239
# Epoch 42/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0261 - val_loss: 0.0023 - val_mean_absolute_error: 0.0433
# Epoch 43/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0254 - val_loss: 0.0035 - val_mean_absolute_error: 0.0486
# Epoch 44/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0240 - val_loss: 0.0030 - val_mean_absolute_error: 0.0462
# Epoch 45/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 4.0890e-04 - val_mean_absolute_error: 0.0164
# Epoch 46/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - val_loss: 5.0916e-04 - val_mean_absolute_error: 0.0197
# Epoch 47/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0237 - val_loss: 0.0019 - val_mean_absolute_error: 0.0357
# Epoch 48/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0230 - val_loss: 5.1484e-04 - val_mean_absolute_error: 0.0167
# Epoch 49/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0240 - val_loss: 9.5281e-04 - val_mean_absolute_error: 0.0263
# Epoch 50/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.5921e-04 - mean_absolute_error: 0.0221 - val_loss: 7.7658e-04 - val_mean_absolute_error: 0.0219
# Epoch 51/60
# 46/46 [==============================] - 0s 5ms/step - loss: 9.8267e-04 - mean_absolute_error: 0.0224 - val_loss: 0.0027 - val_mean_absolute_error: 0.0452
# Epoch 52/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.5348e-04 - mean_absolute_error: 0.0224 - val_loss: 4.4712e-04 - val_mean_absolute_error: 0.0157
# Epoch 53/60
# 46/46 [==============================] - 0s 5ms/step - loss: 9.2177e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0030 - val_mean_absolute_error: 0.0504
# Epoch 54/60
# 46/46 [==============================] - 0s 5ms/step - loss: 8.7702e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0019 - val_mean_absolute_error: 0.0378
# Epoch 55/60
# 46/46 [==============================] - 0s 5ms/step - loss: 9.3803e-04 - mean_absolute_error: 0.0222 - val_loss: 8.9960e-04 - val_mean_absolute_error: 0.0259
# Epoch 56/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.9316e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0029 - val_mean_absolute_error: 0.0447
# Epoch 57/60
# 46/46 [==============================] - 0s 5ms/step - loss: 8.1831e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0022 - val_mean_absolute_error: 0.0427
# Epoch 58/60
# 46/46 [==============================] - 0s 5ms/step - loss: 8.2965e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0034 - val_mean_absolute_error: 0.0536
# Epoch 59/60
# 46/46 [==============================] - 0s 5ms/step - loss: 7.2949e-04 - mean_absolute_error: 0.0204 - val_loss: 6.8214e-04 - val_mean_absolute_error: 0.0208
# Epoch 60/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.2762e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0017 - val_mean_absolute_error: 0.0297

# %%
from matplotlib import pyplot as plt

loss_per_epoch = modelo.history.history['loss']
plt.figure(figsize=(24,8))
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel('Epochs of the Model', fontsize=35)
plt.ylabel('Loss of the Model', fontsize=35)
plt.title("SOLANO COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")
plt.grid()

# %%
# Print the Prediction in a Array (1 sample, single-step)
y_pred = [y[0] for y in modelo.predict(X_test)]
y_pred = np.array(y_pred)
y_pred
# Out:
# array([0.51124203, 0.5159768 , 0.53570855, 0.5450047 , 0.5458814 ,
#        0.5569418 , 0.56500494, 0.57450765, 0.5805248 , 0.57032216,
#        0.55375254, 0.56021976, 0.56385994, 0.5929577 , 0.6021206 ,
#        0.6226409 , 0.62272674, 0.61214197, 0.61462194, 0.6506569 ,
#        0.7073365 , 0.74830556, 0.77885497, 0.8159717 , 0.86075157,
#        0.9212689 , 0.97089976, 1.046276  , 1.1161362 , 1.2175746 ,
#        1.3067044 , 1.3694215 , 1.4020048 , 1.4308637 , 1.4883304 ,
#        1.5508744 , 1.6098428 , 1.6605716 ], dtype=float32)

# %%
# Predictions to the Original Scale
import numpy as np
y_test_inv = scaler.inverse_transform(Y_test)
y_pred_inv = y_pred.reshape(-1,1)
y_pred_inv = scaler.inverse_transform(y_pred_inv)

labels = ['Aug-2019', 'Sept-2019', 'Oct-2019', 'Nov-2019', 'Dec-2019', 'Jan-2020','Feb-2020','March-2020', 'Apr-2020', 'May-2020', 'Jun-2020', 'July-2020', 'June-2020', 'July-2020', 'July-2020', 'Aug-2020',
          'Sept-2002', 'Oct-2020', 'Nov-2020',	'Dec-2020',	'Jan-2021',	'Feb-2021',	'March-2021',	'April-2021',	'May-2021',	'June-2021',	'July-2021',	'Aug-2021',	'Sept-2021',	'Oct-2021',	'Nov-2021',	'Dec-2021',	'Jan-2022','Feb-2022',	'March-2022',	'April-2022',	'May-2022']
x = np.arange(len(labels))  # the label locations
fig, ax = plt.subplots(figsize=(24,8))
plt.plot(y_test_inv[0:38],color='blue',label='test', linewidth=4.0)
plt.plot(y_pred_inv[0:38],color='orange',label='prediction', linewidth=4.0)
ax.set_xticks(x)
ax.set_xticklabels(
    labels, 
    rotation=45, 
    ha="right",  
    rotation_mode="anchor") 
ax.legend()

plt.xlabel('Period of Time', fontsize=35)
plt.ylabel('Prices-USD', fontsize=35)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title("SOLANO COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")

plt.legend();

# %%
# Drawing the Absolute Error as USD
labels = ['Aug-2019', 'Sept-2019', 'Oct-2019', 'Nov-2019', 'Dec-2019', 'Jan-2020','Feb-2020','March-2020', 'Apr-2020', 'May-2020', 'Jun-2020', 'July-2020', 'June-2020', 'July-2020', 'July-2020', 'Aug-2020',
          'Sept-2002', 'Oct-2020', 'Nov-2020',	'Dec-2021',	'Jan-2021',	'Feb-2021',	'March-2021',	'April-2021',	'May-2021',	'June-2021',	'July-2021',	'Aug-2021',	'Sept-2021',	'Oct-2021',	'Nov-2021',	'Dec-2021',	'Jan-2022',
          'Feb-2022',	'March-2022',	'April-2022',	'May-2022']
x = np.arange(len(labels))  # the label locations
fig, ax = plt.subplots(figsize=(24,8))
plt.plot(np.abs(y_test_inv-y_pred_inv), color='red')
ax.set_xticks(x)
ax.set_xticklabels(
    labels, 
    rotation=30, 
    ha="right",  
    rotation_mode="anchor") 
ax.legend()
plt.ylabel('Absolute Error (USD)', fontsize=30)
plt.title("SOLANO COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")

#plt.grid()
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'SOLANO COUNTY')

# %%
y_pred_inv
# Out:
# array([[451832.3 ],
#        [452626.03],
#        [455933.78],
#        [457492.2 ],
#        [457639.12],
#        [459493.28],
#        [460844.94],
#        [462437.97],
#        [463446.62],
#        [461736.3 ],
#        [458958.62],
#        [460042.78],
#        [460653.03],
#        [465530.88],
#        [467066.9 ],
#        [470506.84],
#        [470521.22],
#        [468746.8 ],
#        [469162.56],
#        [475203.38],
#        [484704.9 ],
#        [491572.84],
#        [496694.  ],
#        [502916.12],
#        [510422.9 ],
#        [520567.8 ],
#        [528887.75],
#        [541523.56],
#        [553234.6 ],
#        [570239.44],
#        [585180.8 ],
#        [595694.56],
#        [601156.7 ],
#        [605994.5 ],
#        [615628.  ],
#        [626112.6 ],
#        [635997.94],
#        [644501.94]], dtype=float32)

# %% [markdown]
# # **SHASTA COUNTY**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

RealData_df = pd.read_csv(io.BytesIO(uploaded['Shasta County.csv']), index_col='Dates',parse_dates=True)
print(RealData_df)
# Out:
#      <input type="file" id="files-82f46986-eafd-4cf9-b2fc-84fea714105b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82f46986-eafd-4cf9-b2fc-84fea714105b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Shasta County.csv to Shasta County.csv
#             Shasta County
# Dates
# 2000-01-31          78996
# 2000-02-29          78933
# 2000-03-31          79111
# 2000-04-30          79440
# 2000-05-31          79892
# ...                   ...
# 2021-12-31         367201
# 2022-01-31         369854
# 2022-02-28         373751
# 2022-03-31         376361
# 2022-04-30         381462
#
# [268 rows x 1 columns]

# %%
RealData_df = RealData_df.dropna()
RealData_df
# Out:
#             Shasta County
# Dates
# 2000-01-31          78996
# 2000-02-29          78933
# 2000-03-31          79111
# 2000-04-30          79440
# 2000-05-31          79892
# ...                   ...
# 2021-12-31         367201
# 2022-01-31         369854
# 2022-02-28         373751
# 2022-03-31         376361
# 2022-04-30         381462
#
# [268 rows x 1 columns]

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(24, 8)})
RealData_df['Shasta County'].plot(linewidth=2.5);
#RealData_df.plot

# %%
len(RealData_df)
# Out:
# 268

# %%
DATOS = RealData_df['Shasta County'].values

# Primero dividamos los sets entre train y test
# En este caso la partición no puede ser aleatoria
# (se debe preservar el orden de la secuencia)
TRAIN_SIZE = 0.85
idx = round(len(DATOS)*TRAIN_SIZE)
datos_train = DATOS[0:idx]
datos_test = DATOS[idx:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler = MinMaxScaler(feature_range=(-1,1))
datos_train_s = scaler.fit_transform(datos_train.reshape(-1,1))
datos_test_s = scaler.transform(datos_test.reshape(-1,1))

LONG_SEC = 2

X_train, Y_train = [], []
for i in range(len(datos_train_s)-LONG_SEC):
  X_train.append(datos_train_s[i:i+LONG_SEC])
  Y_train.append(datos_train_s[i+LONG_SEC])

X_test, Y_test = [], []
for i in range(len(datos_test_s)-LONG_SEC):
  X_test.append(datos_test_s[i:i+LONG_SEC])
  Y_test.append(datos_test_s[i+LONG_SEC])

X_train, Y_train = np.array(X_train), np.array(Y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test, Y_test = np.array(X_test), np.array(Y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (226, 2, 1) (226, 1)
# (38, 2, 1) (38, 1)

# %%
RealData_df['Shasta County'].iloc[0:idx].plot(linewidth=4.5, label='train', figsize=(24,8))
RealData_df['Shasta County'].iloc[idx:].plot(linewidth=4.5, color='orange', label='test')
plt.title("SHASTA COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")
plt.xlabel('Period of Time', fontsize=35)
plt.ylabel('Prices-USD', fontsize=35)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend();

# %%
# Creating the LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop, Adam
import tensorflow as tf

# Seed for Random Generators
SEED = 88
tf.random.set_seed(SEED)
np.random.seed(SEED)

# El modelo
N_UNITS = 150
modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=(LONG_SEC,1)))
modelo.add(Dense(1))

# %%
# Compilación y entrenamiento
optimizador = RMSprop(learning_rate=0.0005)
modelo.compile(optimizer=optimizador, loss='mse', metrics='mean_absolute_error')

# Entrenamiento
EPOCHS = 60
BATCH_SIZE = 5
modelo.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
           validation_data = (X_test, Y_test))
# Out:
# Epoch 1/60
# 46/46 [==============================] - 3s 14ms/step - loss: 0.1919 - mean_absolute_error: 0.3671 - val_loss: 0.9966 - val_mean_absolute_error: 0.9661
# Epoch 2/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0419 - mean_absolute_error: 0.1555 - val_loss: 0.1430 - val_mean_absolute_error: 0.3491
# Epoch 3/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0341 - val_loss: 0.0261 - val_mean_absolute_error: 0.1304
# Epoch 4/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0274 - val_loss: 0.0193 - val_mean_absolute_error: 0.1119
# Epoch 5/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0275 - val_loss: 0.0128 - val_mean_absolute_error: 0.0879
# Epoch 6/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0271 - val_loss: 0.0058 - val_mean_absolute_error: 0.0590
# Epoch 7/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0276 - val_loss: 0.0072 - val_mean_absolute_error: 0.0637
# Epoch 8/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 0.0070 - val_mean_absolute_error: 0.0626
# Epoch 9/60
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0266 - val_loss: 0.0097 - val_mean_absolute_error: 0.0749
# Epoch 10/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 0.0130 - val_mean_absolute_error: 0.0899
# Epoch 11/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0263 - val_loss: 0.0126 - val_mean_absolute_error: 0.0909
# Epoch 12/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 0.0044 - val_mean_absolute_error: 0.0512
# Epoch 13/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0248 - val_loss: 0.0023 - val_mean_absolute_error: 0.0408
# Epoch 14/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0263 - val_loss: 0.0035 - val_mean_absolute_error: 0.0481
# Epoch 15/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0256 - val_loss: 0.0179 - val_mean_absolute_error: 0.1151
# Epoch 16/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 0.0176 - val_mean_absolute_error: 0.1158
# Epoch 17/60
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 0.0123 - val_mean_absolute_error: 0.0926
# Epoch 18/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.7538e-04 - mean_absolute_error: 0.0251 - val_loss: 0.0094 - val_mean_absolute_error: 0.0799
# Epoch 19/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.7741e-04 - mean_absolute_error: 0.0245 - val_loss: 0.0182 - val_mean_absolute_error: 0.1192
# Epoch 20/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.5819e-04 - mean_absolute_error: 0.0247 - val_loss: 0.0028 - val_mean_absolute_error: 0.0419
# Epoch 21/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.5311e-04 - mean_absolute_error: 0.0248 - val_loss: 0.0087 - val_mean_absolute_error: 0.0769
# Epoch 22/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.7555e-04 - mean_absolute_error: 0.0251 - val_loss: 0.0049 - val_mean_absolute_error: 0.0522
# Epoch 23/60
# 46/46 [==============================] - 0s 4ms/step - loss: 9.0756e-04 - mean_absolute_error: 0.0241 - val_loss: 0.0158 - val_mean_absolute_error: 0.1106
# Epoch 24/60
# 46/46 [==============================] - 0s 4ms/step - loss: 8.9617e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0034 - val_mean_absolute_error: 0.0452
# Epoch 25/60
# 46/46 [==============================] - 0s 4ms/step - loss: 8.6635e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0078 - val_mean_absolute_error: 0.0714
# Epoch 26/60
# 46/46 [==============================] - 0s 4ms/step - loss: 8.4882e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0021 - val_mean_absolute_error: 0.0378
# Epoch 27/60
# 46/46 [==============================] - 0s 4ms/step - loss: 8.1962e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0145 - val_mean_absolute_error: 0.1077
# Epoch 28/60
# 46/46 [==============================] - 0s 4ms/step - loss: 8.2490e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0016 - val_mean_absolute_error: 0.0326
# Epoch 29/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.4363e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0020 - val_mean_absolute_error: 0.0361
# Epoch 30/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.7170e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0059 - val_mean_absolute_error: 0.0587
# Epoch 31/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.8658e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0090 - val_mean_absolute_error: 0.0796
# Epoch 32/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.4208e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0031 - val_mean_absolute_error: 0.0425
# Epoch 33/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.1155e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0018 - val_mean_absolute_error: 0.0355
# Epoch 34/60
# 46/46 [==============================] - 0s 4ms/step - loss: 7.1690e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0054 - val_mean_absolute_error: 0.0571
# Epoch 35/60
# 46/46 [==============================] - 0s 4ms/step - loss: 6.8744e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0014 - val_mean_absolute_error: 0.0299
# Epoch 36/60
# 46/46 [==============================] - 0s 4ms/step - loss: 6.9255e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0012 - val_mean_absolute_error: 0.0295
# Epoch 37/60
# 46/46 [==============================] - 0s 4ms/step - loss: 6.3425e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0028 - val_mean_absolute_error: 0.0396
# Epoch 38/60
# 46/46 [==============================] - 0s 4ms/step - loss: 6.1408e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0045 - val_mean_absolute_error: 0.0517
# Epoch 39/60
# 46/46 [==============================] - 0s 5ms/step - loss: 6.1240e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0019 - val_mean_absolute_error: 0.0389
# Epoch 40/60
# 46/46 [==============================] - 0s 4ms/step - loss: 5.7527e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0088 - val_mean_absolute_error: 0.0842
# Epoch 41/60
# 46/46 [==============================] - 0s 4ms/step - loss: 6.1235e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 42/60
# 46/46 [==============================] - 0s 5ms/step - loss: 6.1418e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0016 - val_mean_absolute_error: 0.0302
# Epoch 43/60
# 46/46 [==============================] - 0s 6ms/step - loss: 5.7182e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0042 - val_mean_absolute_error: 0.0584
# Epoch 44/60
# 46/46 [==============================] - 0s 6ms/step - loss: 5.5513e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0028 - val_mean_absolute_error: 0.0398
# Epoch 45/60
# 46/46 [==============================] - 0s 6ms/step - loss: 5.7759e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0011 - val_mean_absolute_error: 0.0296
# Epoch 46/60
# 46/46 [==============================] - 0s 6ms/step - loss: 5.7284e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 47/60
# 46/46 [==============================] - 0s 6ms/step - loss: 5.3052e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0050 - val_mean_absolute_error: 0.0590
# Epoch 48/60
# 46/46 [==============================] - 0s 7ms/step - loss: 5.4518e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0020 - val_mean_absolute_error: 0.0332
# Epoch 49/60
# 46/46 [==============================] - 0s 6ms/step - loss: 5.0431e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 50/60
# 46/46 [==============================] - 0s 6ms/step - loss: 4.9792e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 51/60
# 46/46 [==============================] - 0s 7ms/step - loss: 4.7066e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 52/60
# 46/46 [==============================] - 0s 6ms/step - loss: 5.0604e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0023 - val_mean_absolute_error: 0.0356
# Epoch 53/60
# 46/46 [==============================] - 0s 7ms/step - loss: 4.8096e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0016 - val_mean_absolute_error: 0.0292
# Epoch 54/60
# 46/46 [==============================] - 0s 6ms/step - loss: 4.8694e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0029 - val_mean_absolute_error: 0.0412
# Epoch 55/60
# 46/46 [==============================] - 0s 4ms/step - loss: 4.5412e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0011 - val_mean_absolute_error: 0.0286
# Epoch 56/60
# 46/46 [==============================] - 0s 4ms/step - loss: 4.5994e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0053 - val_mean_absolute_error: 0.0594
# Epoch 57/60
# 46/46 [==============================] - 0s 4ms/step - loss: 3.8617e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0014 - val_mean_absolute_error: 0.0286
# Epoch 58/60
# 46/46 [==============================] - 0s 4ms/step - loss: 4.3938e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0029 - val_mean_absolute_error: 0.0404
# Epoch 59/60
# 46/46 [==============================] - 0s 4ms/step - loss: 4.0103e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0011 - val_mean_absolute_error: 0.0287
# Epoch 60/60
# 46/46 [==============================] - 0s 4ms/step - loss: 4.2518e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0017 - val_mean_absolute_error: 0.0350

# %%
from matplotlib import pyplot as plt

loss_per_epoch = modelo.history.history['loss']
plt.figure(figsize=(24,8))
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel('Epochs of the Model', fontsize=35)
plt.ylabel('Loss of the Model', fontsize=35)
plt.title("SHASTA COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")
plt.grid()

# %%
# Print the Prediction in a Array (1 sample, single-step)
y_pred = [y[0] for y in modelo.predict(X_test)]
y_pred = np.array(y_pred)
y_pred
# Out:
# array([1.0783265, 1.0854759, 1.098033 , 1.1198547, 1.1534832, 1.1719604,
#        1.1752032, 1.1771472, 1.1811215, 1.1859876, 1.1916236, 1.1899569,
#        1.1878276, 1.1789923, 1.1949718, 1.2131606, 1.2208909, 1.2306157,
#        1.2546165, 1.3009913, 1.3556205, 1.403212 , 1.4504024, 1.4830256,
#        1.5148994, 1.5576154, 1.6216397, 1.6954557, 1.7678707, 1.8475358,
#        1.9239149, 1.9896656, 2.0171025, 2.0246537, 2.0373685, 2.059006 ,
#        2.091315 , 2.1204827], dtype=float32)

# %%
# Predictions to the Original Scale
import numpy as np
y_test_inv = scaler.inverse_transform(Y_test)
y_pred_inv = y_pred.reshape(-1,1)
y_pred_inv = scaler.inverse_transform(y_pred_inv)

labels = ['Aug-2019', 'Sept-2019', 'Oct-2019', 'Nov-2019', 'Dec-2019', 'Jan-2020','Feb-2020','March-2020', 'Apr-2020', 'May-2020', 'Jun-2020', 'July-2020', 'June-2020', 'July-2020', 'July-2020', 'Aug-2020',
          'Sept-2002', 'Oct-2020', 'Nov-2020',	'Dec-2020',	'Jan-2021',	'Feb-2021',	'March-2021',	'April-2021',	'May-2021',	'June-2021',	'July-2021',	'Aug-2021',	'Sept-2021',	'Oct-2021',	'Nov-2021',	'Dec-2021',	'Jan-2022','Feb-2022',	'March-2022',	'April-2022',	'May-2022']
x = np.arange(len(labels))  # the label locations
fig, ax = plt.subplots(figsize=(24,8))
plt.plot(y_test_inv[0:38],color='blue',label='test', linewidth=4.0)
plt.plot(y_pred_inv[0:38],color='orange',label='prediction', linewidth=4.0)
ax.set_xticks(x)
ax.set_xticklabels(
    labels, 
    rotation=45, 
    ha="right",  
    rotation_mode="anchor") 
ax.legend()

plt.title("SHASTA COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")
plt.xlabel('Period of Time', fontsize=35)
plt.ylabel('Prices-USD', fontsize=35)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend();

# %%
# Drawing the Absolute Error as USD
labels = ['Aug-2019', 'Sept-2019', 'Oct-2019', 'Nov-2019', 'Dec-2019', 'Jan-2020','Feb-2020','March-2020', 'Apr-2020', 'May-2020', 'Jun-2020', 'July-2020', 'June-2020', 'July-2020', 'July-2020', 'Aug-2020',
          'Sept-2002', 'Oct-2020', 'Nov-2020',	'Dec-2021',	'Jan-2021',	'Feb-2021',	'March-2021',	'April-2021',	'May-2021',	'June-2021',	'July-2021',	'Aug-2021',	'Sept-2021',	'Oct-2021',	'Nov-2021',	'Dec-2021',	'Jan-2022',
          'Feb-2022',	'March-2022',	'April-2022',	'May-2022']
x = np.arange(len(labels))  # the label locations
fig, ax = plt.subplots(figsize=(24,8))
plt.plot(np.abs(y_test_inv-y_pred_inv), color='red')
ax.set_xticks(x)
ax.set_xticklabels(
    labels, 
    rotation=30, 
    ha="right",  
    rotation_mode="anchor") 
ax.legend()
plt.ylabel('Absolute Error (USD)', fontsize=30)
plt.title("SHASTA COUNTY", fontsize=60,backgroundcolor='blue', color="white", fontweight="bold")
#plt.grid()
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'SHASTA COUNTY')

# %%
y_pred_inv
# Out:
# array([[276697.2 ],
#        [277377.5 ],
#        [278572.38],
#        [280648.84],
#        [283848.78],
#        [285606.97],
#        [285915.53],
#        [286100.53],
#        [286478.7 ],
#        [286941.75],
#        [287478.03],
#        [287319.44],
#        [287116.84],
#        [286276.1 ],
#        [287796.66],
#        [289527.4 ],
#        [290262.97],
#        [291188.34],
#        [293472.16],
#        [297884.97],
#        [303083.25],
#        [307611.8 ],
#        [312102.25],
#        [315206.53],
#        [318239.5 ],
#        [322304.16],
#        [328396.44],
#        [335420.44],
#        [342311.12],
#        [349891.7 ],
#        [357159.6 ],
#        [363416.12],
#        [366026.9 ],
#        [366745.44],
#        [367955.3 ],
#        [370014.25],
#        [373088.62],
#        [375864.1 ]], dtype=float32)
